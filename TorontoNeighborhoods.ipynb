# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods

# %% [markdown]
# This Jupyter Notebook is mainly used for the __Capstone Projekt__ in the Coursera/IBM course _Applied Data Science Capstone_

# %% [markdown]
# ## Week 3 - Toronto Neighborhoods

# %% [markdown]
# For this assignment, you will be required to explore and cluster the neighborhoods in Toronto.
#
# 1. Start by creating a new Notebook for this assignment.
# 2. Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe like the one shown below:

# %% [markdown]
# ![Coursera image](https://d3c33hcgiwev3.cloudfront.net/imageAssetProxy.v1/7JXaz3NNEeiMwApe4i-fLg_40e690ae0e927abda2d4bde7d94ed133_Screen-Shot-2018-06-18-at-7.17.57-PM.png?expiry=1589414400000&hmac=XzHQN-7m3GJQYhlT8NyGjgPuEWl3iivMUr8EvLVFbVM)

# %% [markdown]
# ## Alternative 1 - pandas

# %%
# Import libraries and packages
import pandas as pd
import numpy as np

# %%
# Returns list of all tables on page
tables = pd.read_html(wikipedia_url)
for table in tables:
    if 'Postal Code' in table:
        pc_df = table
pc_df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                                NaN
#
# [180 rows x 3 columns]

# %% [markdown]
# ## Alternative 2 - BeautifulSoup

# %%
# Import libraries and packages
import requests
import lxml.html as lh
from bs4 import BeautifulSoup

# %%
# Wikipedia URL
wikipedia_url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# Request the URL
wikipedia_page = requests.get(wikipedia_url)

# Store the URL/page
wikipedia_content = BeautifulSoup(wikipedia_page.content, 'html5lib')

# Get right table with 'Postal Code' in the header of the table
tables = wikipedia_content.find_all('table', class_='sortable')
for table in tables:
    ths = table.find_all('th')
    header = [th.text.strip() for th in ths]
    if 'Postal Code' in header:
        df = pd.read_html(str(table), index_col=None, header=0)[0]
        break
df.describe()
#df.head()
# Out:
#        Postal Code       Borough Neighborhood
# count          180           180          103
# unique         180            11           98
# top            M1M  Not assigned    Downsview
# freq             1            77            4

# %%
# Wikipedia URL
wikipedia_url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# Request the URL
wikipedia_page = requests.get(wikipedia_url)

# Store the URL/page
wikipedia_content = BeautifulSoup(wikipedia_page.content, 'html5lib')

# Get right table with 'Postal Code' in the header of the table
tables = wikipedia_content.find_all('table', class_='sortable')
header = []
#for i, table in enumerate(tables):
for table in tables:
    ths = table.find_all('th')
    headings = [th.text.strip() for th in ths]
    if 'Postal Code' in headings:
        header = headings
        break


        
        
London_table = pd.read_html(str(tables[0]), index_col=None, header=0)[0]
London_table.head()

tbody = table.find('tbody')        
#print(tbody)  
print(header)
content = []
for row in table.find_all('tr'):
    column = [col.text.strip() for col in row.find_all('td')]
    content.append(column)

content = np.asarray(content)
print(len(content))
#print(content)

df = pd.DataFrame(content)
df
# Out:
# ['Postal Code', 'Borough', 'Neighborhood']
# 181
#                                                      0
# 0                                                   []
# 1                                [M1A, Not assigned, ]
# 2                                [M2A, Not assigned, ]
# 3                         [M3A, North York, Parkwoods]
# 4                  [M4A, North York, Victoria Village]
# ..                                                 ...
# 176                              [M5Z, Not assigned, ]
# 177                              [M6Z, Not assigned, ]
# 178                              [M7Z, Not assigned, ]
# 179  [M8Z, Etobicoke, Mimico NW, The Queensway West...
# 180                              [M9Z, Not assigned, ]
#
# [181 rows x 1 columns]

# %%
# Returns list of all tables on page
tables = pd.read_html(wikipedia_url)
for table in tables:
    if 'Postal Code' in table:
        pc_df = table
pc_df

# Get header from first table row
#header = []
#for cell in table_cells[0]:
#    header.append(cell.text_content().rstrip())
#print('Header of table: {}'.format(header))

l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
pd.DataFrame(l, columns=["A", "B", ...])
# Out:
# Header of table: ['Postal Code', 'Borough', 'Neighborhood']

# %% [markdown]
# Since the first table row contains the header, parse the header information from the first table row and store it in a list

# %%
# Get header from first table row
header = []
for cell in table_cells[0]:
    header.append(cell.text_content().rstrip())
print('Header of table: {}'.format(header))
# Out:
# Header of table: ['Postal Code', 'Borough', 'Neighborhood']

# %% [markdown]
# Read table information into lists

# %%
for i, cell in enumerate(table_cells[1:]): # Start at second row, since first row is the header
    print('Cell {} contains: {}'.format(i, cell.text_content().rstrip()))
# Out:
# Cell 0 contains:
# M1A
#
# Not assigned
# Cell 1 contains:
# M2A
#
# Not assigned
# Cell 2 contains:
# M3A
#
# North York
#
# Parkwoods
# Cell 3 contains:
# M4A
#
# North York
#
# Victoria Village
# Cell 4 contains:
# M5A
#
# Downtown Toronto
#
# Regent Park, Harbourfront
# Cell 5 contains:
# M6A
#
# North York
#
# Lawrence Manor, Lawrence Heights
# Cell 6 contains:
# M7A
#
# Downtown Toronto
#
# Queen's Park, Ontario Provincial Government
# Cell 7 contains:
# M8A
#
# Not assigned
# Cell 8 contains:
# M9A
#
# Etobicoke
#
# Islington Avenue
# Cell 9 contains:
# M1B
#
# Scarborough
#
# Malvern, Rouge
# Cell 10 contains:
# M2B
#
# Not assigned
# Cell 11 contains:
# M3B
#
# North York
#
# Don Mills
# Cell 12 contains:
# M4B
#
# East York
#
# Parkview Hill, Woodbine Gardens
# Cell 13 contains:
# M5B
#
# Downtown Toronto
#
# Garden District, Ryerson
# Cell 14 contains:
# M6B
#
# North York
#
# Glencairn
# Cell 15 contains:
# M7B
#
# Not assigned
# Cell 16 contains:
# M8B
#
# Not assigned
# Cell 17 contains:
# M9B
#
# Etobicoke
#
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Cell 18 contains:
# M1C
#
# Scarborough
#
# Rouge Hill, Port Union, Highland Creek
# Cell 19 contains:
# M2C
#
# Not assigned
# Cell 20 contains:
# M3C
#
# North York
#
# Don Mills
# Cell 21 contains:
# M4C
#
# East York
#
# Woodbine Heights
# Cell 22 contains:
# M5C
#
# Downtown Toronto
#
# St. James Town
# Cell 23 contains:
# M6C
#
# York
#
# Humewood-Cedarvale
# Cell 24 contains:
# M7C
#
# Not assigned
# Cell 25 contains:
# M8C
#
# Not assigned
# Cell 26 contains:
# M9C
#
# Etobicoke
#
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Cell 27 contains:
# M1E
#
# Scarborough
#
# Guildwood, Morningside, West Hill
# Cell 28 contains:
# M2E
#
# Not assigned
# Cell 29 contains:
# M3E
#
# Not assigned
# Cell 30 contains:
# M4E
#
# East Toronto
#
# The Beaches
# Cell 31 contains:
# M5E
#
# Downtown Toronto
#
# Berczy Park
# Cell 32 contains:
# M6E
#
# York
#
# Caledonia-Fairbanks
# Cell 33 contains:
# M7E
#
# Not assigned
# Cell 34 contains:
# M8E
#
# Not assigned
# Cell 35 contains:
# M9E
#
# Not assigned
# Cell 36 contains:
# M1G
#
# Scarborough
#
# Woburn
# Cell 37 contains:
# M2G
#
# Not assigned
# Cell 38 contains:
# M3G
#
# Not assigned
# Cell 39 contains:
# M4G
#
# East York
#
# Leaside
# Cell 40 contains:
# M5G
#
# Downtown Toronto
#
# Central Bay Street
# Cell 41 contains:
# M6G
#
# Downtown Toronto
#
# Christie
# Cell 42 contains:
# M7G
#
# Not assigned
# Cell 43 contains:
# M8G
#
# Not assigned
# Cell 44 contains:
# M9G
#
# Not assigned
# Cell 45 contains:
# M1H
#
# Scarborough
#
# Cedarbrae
# Cell 46 contains:
# M2H
#
# North York
#
# Hillcrest Village
# Cell 47 contains:
# M3H
#
# North York
#
# Bathurst Manor, Wilson Heights, Downsview North
# Cell 48 contains:
# M4H
#
# East York
#
# Thorncliffe Park
# Cell 49 contains:
# M5H
#
# Downtown Toronto
#
# Richmond, Adelaide, King
# Cell 50 contains:
# M6H
#
# West Toronto
#
# Dufferin, Dovercourt Village
# Cell 51 contains:
# M7H
#
# Not assigned
# Cell 52 contains:
# M8H
#
# Not assigned
# Cell 53 contains:
# M9H
#
# Not assigned
# Cell 54 contains:
# M1J
#
# Scarborough
#
# Scarborough Village
# Cell 55 contains:
# M2J
#
# North York
#
# Fairview, Henry Farm, Oriole
# Cell 56 contains:
# M3J
#
# North York
#
# Northwood Park, York University
# Cell 57 contains:
# M4J
#
# East York
#
# East Toronto
# Cell 58 contains:
# M5J
#
# Downtown Toronto
#
# Harbourfront East, Union Station, Toronto Islands
# Cell 59 contains:
# M6J
#
# West Toronto
#
# Little Portugal, Trinity
# Cell 60 contains:
# M7J
#
# Not assigned
# Cell 61 contains:
# M8J
#
# Not assigned
# Cell 62 contains:
# M9J
#
# Not assigned
# Cell 63 contains:
# M1K
#
# Scarborough
#
# Kennedy Park, Ionview, East Birchmount Park
# Cell 64 contains:
# M2K
#
# North York
#
# Bayview Village
# Cell 65 contains:
# M3K
#
# North York
#
# Downsview
# Cell 66 contains:
# M4K
#
# East Toronto
#
# The Danforth West, Riverdale
# Cell 67 contains:
# M5K
#
# Downtown Toronto
#
# Toronto Dominion Centre, Design Exchange
# Cell 68 contains:
# M6K
#
# West Toronto
#
# Brockton, Parkdale Village, Exhibition Place
# Cell 69 contains:
# M7K
#
# Not assigned
# Cell 70 contains:
# M8K
#
# Not assigned
# Cell 71 contains:
# M9K
#
# Not assigned
# Cell 72 contains:
# M1L
#
# Scarborough
#
# Golden Mile, Clairlea, Oakridge
# Cell 73 contains:
# M2L
#
# North York
#
# York Mills, Silver Hills
# Cell 74 contains:
# M3L
#
# North York
#
# Downsview
# Cell 75 contains:
# M4L
#
# East Toronto
#
# India Bazaar, The Beaches West
# Cell 76 contains:
# M5L
#
# Downtown Toronto
#
# Commerce Court, Victoria Hotel
# Cell 77 contains:
# M6L
#
# North York
#
# North Park, Maple Leaf Park, Upwood Park
# Cell 78 contains:
# M7L
#
# Not assigned
# Cell 79 contains:
# M8L
#
# Not assigned
# Cell 80 contains:
# M9L
#
# North York
#
# Humber Summit
# Cell 81 contains:
# M1M
#
# Scarborough
#
# Cliffside, Cliffcrest, Scarborough Village West
# Cell 82 contains:
# M2M
#
# North York
#
# Willowdale, Newtonbrook
# Cell 83 contains:
# M3M
#
# North York
#
# Downsview
# Cell 84 contains:
# M4M
#
# East Toronto
#
# Studio District
# Cell 85 contains:
# M5M
#
# North York
#
# Bedford Park, Lawrence Manor East
# Cell 86 contains:
# M6M
#
# York
#
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Cell 87 contains:
# M7M
#
# Not assigned
# Cell 88 contains:
# M8M
#
# Not assigned
# Cell 89 contains:
# M9M
#
# North York
#
# Humberlea, Emery
# Cell 90 contains:
# M1N
#
# Scarborough
#
# Birch Cliff, Cliffside West
# Cell 91 contains:
# M2N
#
# North York
#
# Willowdale
# Cell 92 contains:
# M3N
#
# North York
#
# Downsview
# Cell 93 contains:
# M4N
#
# Central Toronto
#
# Lawrence Park
# Cell 94 contains:
# M5N
#
# Central Toronto
#
# Roselawn
# Cell 95 contains:
# M6N
#
# York
#
# Runnymede, The Junction North
# Cell 96 contains:
# M7N
#
# Not assigned
# Cell 97 contains:
# M8N
#
# Not assigned
# Cell 98 contains:
# M9N
#
# York
#
# Weston
# Cell 99 contains:
# M1P
#
# Scarborough
#
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Cell 100 contains:
# M2P
#
# North York
#
# York Mills West
# Cell 101 contains:
# M3P
#
# Not assigned
# Cell 102 contains:
# M4P
#
# Central Toronto
#
# Davisville North
# Cell 103 contains:
# M5P
#
# Central Toronto
#
# Forest Hill North & West
# Cell 104 contains:
# M6P
#
# West Toronto
#
# High Park, The Junction South
# Cell 105 contains:
# M7P
#
# Not assigned
# Cell 106 contains:
# M8P
#
# Not assigned
# Cell 107 contains:
# M9P
#
# Etobicoke
#
# Westmount
# Cell 108 contains:
# M1R
#
# Scarborough
#
# Wexford, Maryvale
# Cell 109 contains:
# M2R
#
# North York
#
# Willowdale
# Cell 110 contains:
# M3R
#
# Not assigned
# Cell 111 contains:
# M4R
#
# Central Toronto
#
# North Toronto West
# Cell 112 contains:
# M5R
#
# Central Toronto
#
# The Annex, North Midtown, Yorkville
# Cell 113 contains:
# M6R
#
# West Toronto
#
# Parkdale, Roncesvalles
# Cell 114 contains:
# M7R
#
# Mississauga
#
# Canada Post Gateway Processing Centre
# Cell 115 contains:
# M8R
#
# Not assigned
# Cell 116 contains:
# M9R
#
# Etobicoke
#
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Cell 117 contains:
# M1S
#
# Scarborough
#
# Agincourt
# Cell 118 contains:
# M2S
#
# Not assigned
# Cell 119 contains:
# M3S
#
# Not assigned
# Cell 120 contains:
# M4S
#
# Central Toronto
#
# Davisville
# Cell 121 contains:
# M5S
#
# Downtown Toronto
#
# University of Toronto, Harbord
# Cell 122 contains:
# M6S
#
# West Toronto
#
# Runnymede, Swansea
# Cell 123 contains:
# M7S
#
# Not assigned
# Cell 124 contains:
# M8S
#
# Not assigned
# Cell 125 contains:
# M9S
#
# Not assigned
# Cell 126 contains:
# M1T
#
# Scarborough
#
# Clarks Corners, Tam O'Shanter, Sullivan
# Cell 127 contains:
# M2T
#
# Not assigned
# Cell 128 contains:
# M3T
#
# Not assigned
# Cell 129 contains:
# M4T
#
# Central Toronto
#
# Moore Park, Summerhill East
# Cell 130 contains:
# M5T
#
# Downtown Toronto
#
# Kensington Market, Chinatown, Grange Park
# Cell 131 contains:
# M6T
#
# Not assigned
# Cell 132 contains:
# M7T
#
# Not assigned
# Cell 133 contains:
# M8T
#
# Not assigned
# Cell 134 contains:
# M9T
#
# Not assigned
# Cell 135 contains:
# M1V
#
# Scarborough
#
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Cell 136 contains:
# M2V
#
# Not assigned
# Cell 137 contains:
# M3V
#
# Not assigned
# Cell 138 contains:
# M4V
#
# Central Toronto
#
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Cell 139 contains:
# M5V
#
# Downtown Toronto
#
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Cell 140 contains:
# M6V
#
# Not assigned
# Cell 141 contains:
# M7V
#
# Not assigned
# Cell 142 contains:
# M8V
#
# Etobicoke
#
# New Toronto, Mimico South, Humber Bay Shores
# Cell 143 contains:
# M9V
#
# Etobicoke
#
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Cell 144 contains:
# M1W
#
# Scarborough
#
# Steeles West, L'Amoreaux West
# Cell 145 contains:
# M2W
#
# Not assigned
# Cell 146 contains:
# M3W
#
# Not assigned
# Cell 147 contains:
# M4W
#
# Downtown Toronto
#
# Rosedale
# Cell 148 contains:
# M5W
#
# Downtown Toronto
#
# Stn A PO Boxes
# Cell 149 contains:
# M6W
#
# Not assigned
# Cell 150 contains:
# M7W
#
# Not assigned
# Cell 151 contains:
# M8W
#
# Etobicoke
#
# Alderwood, Long Branch
# Cell 152 contains:
# M9W
#
# Etobicoke
#
# Northwest
# Cell 153 contains:
# M1X
#
# Scarborough
#
# Upper Rouge
# Cell 154 contains:
# M2X
#
# Not assigned
# Cell 155 contains:
# M3X
#
# Not assigned
# Cell 156 contains:
# M4X
#
# Downtown Toronto
#
# St. James Town, Cabbagetown
# Cell 157 contains:
# M5X
#
# Downtown Toronto
#
# First Canadian Place, Underground city
# Cell 158 contains:
# M6X
#
# Not assigned
# Cell 159 contains:
# M7X
#
# Not assigned
# Cell 160 contains:
# M8X
#
# Etobicoke
#
# The Kingsway, Montgomery Road, Old Mill North
# Cell 161 contains:
# M9X
#
# Not assigned
# Cell 162 contains:
# M1Y
#
# Not assigned
# Cell 163 contains:
# M2Y
#
# Not assigned
# Cell 164 contains:
# M3Y
#
# Not assigned
# Cell 165 contains:
# M4Y
#
# Downtown Toronto
#
# Church and Wellesley
# Cell 166 contains:
# M5Y
#
# Not assigned
# Cell 167 contains:
# M6Y
#
# Not assigned
# Cell 168 contains:
# M7Y
#
# East Toronto
#
# Business reply mail Processing Centre
# Cell 169 contains:
# M8Y
#
# Etobicoke
#
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Cell 170 contains:
# M9Y
#
# Not assigned
# Cell 171 contains:
# M1Z
#
# Not assigned
# Cell 172 contains:
# M2Z
#
# Not assigned
# Cell 173 contains:
# M3Z
#
# Not assigned
# Cell 174 contains:
# M4Z
#
# Not assigned
# Cell 175 contains:
# M5Z
#
# Not assigned
# Cell 176 contains:
# M6Z
#
# Not assigned
# Cell 177 contains:
# M7Z
#
# Not assigned
# Cell 178 contains:
# M8Z
#
# Etobicoke
#
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# Cell 179 contains:
# M9Z
#
# Not assigned
# Cell 180 contains:
#
#
# Canadian postal codes
# Cell 181 contains:
#
#
#
# NL
#
# NS
#
# PE
#
# NB
#
# QC
#
# ON
#
# MB
#
# SK
#
# AB
#
# BC
#
# NU/NT
#
# YT
#
#
# A
#
# B
#
# C
#
# E
#
# G
#
# H
#
# J
#
# K
#
# L
#
# M
#
# N
#
# P
#
# R
#
# S
#
# T
#
# V
#
# X
#
# Y
# Cell 182 contains:
# NL
#
# NS
#
# PE
#
# NB
#
# QC
#
# ON
#
# MB
#
# SK
#
# AB
#
# BC
#
# NU/NT
#
# YT
# Cell 183 contains:
# A
#
# B
#
# C
#
# E
#
# G
#
# H
#
# J
#
# K
#
# L
#
# M
#
# N
#
# P
#
# R
#
# S
#
# T
#
# V
#
# X
#
# Y
